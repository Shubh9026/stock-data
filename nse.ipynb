# %%
import requests
from bs4 import BeautifulSoup

# URL of the page containing the PDF links
url = "https://www.nseindia.com/companies-listing/corporate-filings-annual-reports?symbol=SHERA&tabIndex=sme"  # Replace this with the exact URL

# Define headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0",
    "Accept": "*/*",
    "Referer": url,
    "Connection": "keep-alive",
    'Cookie': '_abck=B491639F2A18A8817DC4957DCB13741B~0~...~-1~-1~-1; RT="z=1&dm=nseindia.com&si=d2ac7607-3be9-4c01-9ac5-ba14ccc2fc87&ss=m2av56ej&sl=0&se=8c&tt=0&bcn=%2F%2F684d0d4b.akstat.io%2F&ul=ofxp"; _ga_87M7PJ3R97=GS1.1.1729022146.18.1.1729022843.60.0.0; _ga=GA1.1.1682247845.1728797628; nseQuoteSymbols=[{"symbol":"INNOVANA","identifier":null,"type":"equity"},{"symbol":"SAHAJ","identifier":null,"type":"equity"},{"symbol":"SANGANI","identifier":null,"type":"equity"},{"symbol":"TATACAPHSG","identifier":null,"type":"bonds"},{"symbol":"SHANTHALA","identifier":null,"type":"equity"}]; defaultLang=en; bm_sz=AAEB9FACE3C3C26BD74773BC6D2256AB~...~4601156~3159863; nsit=eDI9XZpWe7m9kmCqFcaBcOps; ak_bmsc=BCF2F0120D470F43599854C411A8C099~000000000000000000000000000000~...; bm_sv=6B5004890B1C54605C012919B3E0B0CC~~1; ak_bmsc=00085E8926B3EFB13FF454C317FA5E85~000000000000000000000000000000~; nseappid=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhcGkubnNlIiwiYXVkIjoiYXBpLm5zZSIsImlhdCI6MTcyOTAyMjE0NiwiZXhwIjoxNzI5MDI5MzQ2fQ.EIshWEfZJXDY2yijBSKbH7HUBKo3WMbuL3StMsbOiz0; AKA_A2=A'
}
# Send GET request to the URL
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    print(soup)
    # Find the table cell containing the PDF link
    pdf_links = soup.find_all('td', class_='text-center')
    print(pdf_links)
    print(1)
    # Extract PDF URLs
    for td in pdf_links:
        a_tag = td.find('a', href=True)
        if a_tag:
            print(2)
            pdf_url = a_tag['href']
            print(f"Found PDF link: {pdf_url}")
else:
    print(f"Failed to retrieve the page, status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <title>
#     Corporate Filings Annual Reports - Equity, SME - NSE India
# </title>
# <meta content="Corporate Filings Annual Reports-  Get latest information about Corporate Filings Annual Reports - Equity, SME and more. Learn more about Corporate Filings Annual Reports Today, visit NSE India." name="description"/>
# <meta content="" name="keywords"/>
# <meta content="index,follow" name="robots"/>
# <link href="/assets/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="" property="og:title"/>
# <meta content="" property="og:description"/>
# ...

# %%
user_agent = "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"

# %%
encoded_nse_code = "SHERA"

# %%
import requests
import pandas as pd
import time
import random
from tqdm import tqdm  # Progress bar
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from urllib.parse import quote
import os

# %%
# Load NSE codes from a CSV file
nse_codes_file = 'refined_companies_tick.csv'  # Path to your input CSV file
output_file = 'annual_reports2.csv'  # Path for the final output CSV file
temp_output_file = 'temp_annual_reports2.csv'  # Temporary file to save progress

# Load NSE codes into a list
nse_codes_df = pd.read_csv(nse_codes_file)
nse_codes = nse_codes_df['NSE Code'].tolist()

# %%
# Load previous results if temp file exists
if os.path.exists(temp_output_file):
    previous_results_df = pd.read_csv(temp_output_file)
    fetched_nse_codes = previous_results_df['nse_code'].unique().tolist()
    print(f"Resuming from checkpoint. {len(fetched_nse_codes)} companies already processed.")
else:
    previous_results_df = pd.DataFrame()
    fetched_nse_codes = []

# Filter out NSE codes that have already been fetched
nse_codes = [code for code in nse_codes if code not in fetched_nse_codes]

# List of rotating User-Agent headers for each request
USER_AGENTS = [
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
]

# %%
def fetch_annual_reports(session, nse_code):
    # Rotate User-Agent for each request
    user_agent = random.choice(USER_AGENTS)

    # URL encode the NSE code to handle special characters like & and spaces
    encoded_nse_code = quote(nse_code)

    # Step 1: Make an initial request to get cookies (no need to encode in this URL)
    session.get(f'https://www.nseindia.com/get-quotes/equity?symbol={nse_code}', headers={
        'User-Agent': user_agent,
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    })

    # Step 2: Use the session with cookies to fetch the API data (use encoded NSE code)
    url = f"https://www.nseindia.com/api/annual-reports?index=equities&symbol={encoded_nse_code}&issuer={encoded_nse_code}"
    headers = {
        'User-Agent': user_agent,
        'Accept': 'application/json, text/javascript, */*; q=0.01',
        'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={encoded_nse_code}',
        'X-Requested-With': 'XMLHttpRequest',
    }

    # Add random delay to slow down requests (longer delay between 5-10 seconds)
    delay = random.uniform(1, 6)
    time.sleep(delay)

    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()  # Raise an error for bad responses
        return response.json().get('data', [])
    except requests.exceptions.HTTPError as err:
        print(f"HTTP error occurred for {nse_code}: {err}")
        return []
    except Exception as err:
        print(f"An error occurred for {nse_code}: {err}")
        return []

# %%
# Initialize a requests session with retry and SSL handling
session = requests.Session()
retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[429, 500, 502, 503, 504])
adapter = HTTPAdapter(max_retries=retries)
session.mount('https://', adapter)

# Initialize results with previously fetched data if any
results = previous_results_df.to_dict('records') if not previous_results_df.empty else []

# %%
# Function to save data incrementally
def save_results():
    results_df = pd.DataFrame(results)
    results_df.to_csv(temp_output_file, index=False)
    print(f"Data saved to {temp_output_file}.")

# %%
# Loop through each NSE code and fetch reports with progress bar
for nse_code in tqdm(nse_codes, desc="Fetching Annual Reports"):
    attempts = 0
    max_attempts = 0  # Set a maximum number of attempts

    while attempts < max_attempts:
        annual_reports = fetch_annual_reports(session, nse_code)
        if annual_reports:
            for report in annual_reports:
                results.append({
                    'nse_code': nse_code,
                    'company_name': report['companyName'],  # Add company name
                    'year': f"{report['fromYr']} - {report['toYr']}",
                    'link': report['fileName']
                })
            # Save progress periodically
            if len(results) % 50 == 0:
                save_results()
            break  # Break if successful
        else:
            attempts += 1
            print(f"Retrying... Attempt {attempts} for {nse_code}")
            time.sleep(1)  # Delay before retrying

# %%
import requests

# Endpoint URL
url = "https://www.nseindia.com/api/corp-info?symbol=SHERA&corpType=annualreport&market=sme"

# Adjust headers, focusing on problematic characters in Cookie
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive",
    "Cookie": (
        "_abck=B491639F2A18A8817DC4957DCB13741B~0~...…bafkso366A; defaultLang=en; bm_sv=36E1078F7E40A38F7B6600D07B54FA5E~~1;"
    ),
    "Host": "www.nseindia.com",
    "Referer": "https://www.nseindia.com/get-quotes/equity?symbol=SHERA",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "TE": "trailers",
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"
}

# Send GET request
response = requests.get(url, headers=headers)

# Check for successful response
if response.status_code == 200:
    data = response.json()  # Parse the JSON data
    print("Fetched data:", data)
else:
    print("Failed to fetch data. Status code:", response.status_code)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[4], line 25
#       7 headers = {
#       8     "Accept": "*/*",
#       9     "Accept-Encoding": "gzip, deflate, br, zstd",
#    (...)
#      21     "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"
#      22 }
#      24 # Send GET request
# ---> 25 response = requests.get(url, headers=headers)
#      27 # Check for successful response
#      28 if response.status_code == 200:
#
# File ~/project/myenv/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
import requests

# Endpoint URL
url = "https://www.nseindia.com/api/corp-info?symbol=SHERA&corpType=annualreport&market=sme"

# Adjust headers, focusing on problematic characters in Cookie
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive",
    "Cookie": "_abck=B491639F2A18A8817DC4957DCB13741B~0~YAAQUUo5F38Zp3OSAQAA2b8llAxaQRtJ...",
    "Host": "www.nseindia.com",
    "Referer": "https://www.nseindia.com/get-quotes/equity?symbol=SHERA",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "TE": "trailers",
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"
}

# Send GET request
response = requests.get(url, headers=headers)

# Check for successful response
if response.status_code == 200:
    data = response.json()  # Parse the JSON data
    print("Fetched data:", data)
else:
    print("Failed to fetch data. Status code:", response.status_code)
# Out:
# Failed to fetch data. Status code: 401

# %%
import requests

# URL to initialize session (NSE main page or the page that sets necessary cookies)
initial_url = "https://www.nseindia.com/get-quotes/equity?symbol=SHERA"

# API endpoint URL for JSON data
api_url = "https://www.nseindia.com/api/corp-info?symbol=SHERA&corpType=annualreport&market=sme"

# Headers used in requests
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive",
    "Referer": initial_url,
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"
}

# Initialize a session
session = requests.Session()

# Step 1: Visit the initial page to set cookies
session.get(initial_url, headers=headers)

# Step 2: Make the API request using the same session with automatically managed cookies
response = session.get(api_url, headers=headers)

# Step 3: Check the response
if response.status_code == 200:
    data = response.json()  # Parse JSON response
    print("Fetched data:", data)
else:
    print("Failed to fetch data. Status code:", response.status_code)
# Out:
# Fetched data: [{'symbol': 'SHERA', 'companyName': 'Shera Energy Limited', 'fromYr': '2023', 'toYr': '2024', 'fileName': 'https://nsearchives.nseindia.com/annual_reports/SME_AR_25208_SHERA_2023_2024_28082024111956.pdf', 'anReportCreateDate': '28-Aug-2024'}, {'symbol': 'SHERA', 'companyName': 'Shera Energy Limited', 'fromYr': '2022', 'toYr': '2023', 'fileName': 'https://nsearchives.nseindia.com/annual_reports/SME_AR_23085_SHERA_2022_2023_30082023124202_08302023130000.zip', 'anReportCreateDate': '30-Aug-2023'}]

# %%
import requests
import pandas as pd
import time

# Paths for input and output CSV files
input_csv_path = '/home/shubh/project/nse_links.csv'
output_csv_path = '/home/shubh/project/extracted_data.csv'

# Load the CSV file containing the NSE links
df = pd.read_csv(input_csv_path)

# Initialize a list to store the results
results = []

# Initialize a session
session = requests.Session()

# Headers for the requests
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive",
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"
}

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Extract the NSE link from the 'report_link' column
    report_link = row['report_link']

    try:
        # Fetch the initial page to set cookies
        session.get(report_link, headers=headers)

        # Construct the API URL
        api_url = f"https://www.nseindia.com/api/corp-info?symbol={report_link.split('=')[-1]}&corpType=annualreport&market=sme"
        
        # Send GET request to the API
        response = session.get(api_url, headers=headers)

        # Check for successful response
        if response.status_code == 200:
            data = response.json()  # Parse JSON response
            results.append(data)  # Append the data to results list
        else:
            print(f"Failed to fetch data for {report_link}. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {report_link}: {e}")

    # Pause between requests
    time.sleep(5)  # or 10 seconds

# Create a DataFrame from the results and save to CSV
results_df = pd.DataFrame(results)
results_df.to_csv(output_csv_path, index=False)

print(f"Data extraction complete. Saved to {output_csv_path}.")
# Out:
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=DKEGL: Expecting value: line 1 column 1 (char 0)
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=AMJUMBO: Expecting value: line 1 column 1 (char 0)
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=AURDIS: Expecting value: line 1 column 2 (char 1)
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=ARISTO: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 40
#      37 api_url = f"https://www.nseindia.com/api/corp-info?symbol={report_link.split('=')[-1]}&corpType=annualreport&market=sme"
#      39 # Send GET request to the API
# ---> 40 response = session.get(api_url, headers=headers)
#      42 # Check for successful response
#      43 if response.status_code == 200:
#
# ...

# %%
import requests
import pandas as pd
import time
import random

# Paths for input and output CSV files
input_csv_path = '/home/shubh/project/nse_links.csv'
output_csv_path = '/home/shubh/project/extracted_data.csv'

# Load the CSV file containing the NSE links
df = pd.read_csv(input_csv_path)

# Initialize a list to store the results
results = []

# Initialize a session
session = requests.Session()

# Headers for the requests
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive",
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"
}

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Extract the NSE link from the 'report_link' column
    report_link = row['report_link']  # Ensure this matches your CSV column name

    for attempt in range(3):  # Retry mechanism
        try:
            # Fetch the initial page to set cookies
            session.get(report_link, headers=headers)

            # Construct the API URL
            api_url = f"https://www.nseindia.com/api/corp-info?symbol={report_link.split('=')[-1]}&corpType=annualreport&market=sme"
            
            # Send GET request to the API
            response = session.get(api_url, headers=headers)

            # Check for successful response
            if response.status_code == 200:
                data = response.json()  # Parse JSON response
                results.append(data)  # Append the data to results list
                break  # Exit the retry loop on success
            else:
                print(f"Failed to fetch data for {report_link}. Status code: {response.status_code}")

        except requests.exceptions.RequestException as e:
            print(f"Error fetching data for {report_link} (attempt {attempt + 1}): {e}")
            time.sleep(5)  # Wait before retrying
        except Exception as e:
            print(f"An unexpected error occurred for {report_link}: {e}")
            break  # Exit the retry loop on unexpected error

    # Pause between requests to avoid overwhelming the server
    sleep_time = random.uniform(5, 10)  # Random sleep between 5 and 10 seconds
    print(f"Waiting for {sleep_time:.2f} seconds before the next request...")
    time.sleep(sleep_time)

# Create a DataFrame from the results and save to CSV
results_df = pd.DataFrame(results)
results_df.to_csv(output_csv_path, index=False)

print(f"Data extraction complete. Saved to {output_csv_path}.")
# Out:
# Waiting for 5.79 seconds before the next request...
# Waiting for 5.83 seconds before the next request...
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=DKEGL (attempt 1): Expecting value: line 1 column 1 (char 0)
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=DKEGL (attempt 2): Expecting value: line 1 column 1 (char 0)
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=DKEGL (attempt 3): Expecting value: line 1 column 1 (char 0)
# Waiting for 5.05 seconds before the next request...
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=AMJUMBO (attempt 1): Expecting value: line 1 column 1 (char 0)
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=AMJUMBO (attempt 2): Expecting value: line 1 column 1 (char 0)
# Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=AMJUMBO (attempt 3): Expecting value: line 1 column 1 (char 0)
# ...

# %%
import requests
import pandas as pd
import time
import random
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)

# Paths for input and output CSV files
input_csv_path = '/home/shubh/project/nse_links.csv'
output_csv_path = '/home/shubh/project/extracted_data.csv'

# Load the CSV file containing the NSE links
df = pd.read_csv(input_csv_path)
logging.info("CSV file loaded successfully.")

# Initialize a session
session = requests.Session()

headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36",
    "Referer": "https://www.nseindia.com",
    "Origin": "https://www.nseindia.com"
}

# Create or open the output CSV file for appending
with open(output_csv_path, 'w') as output_file:
    output_file.write('data\n')  # Write header if needed; adjust accordingly based on expected data structure

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        report_link = row['report_link']  # Ensure this matches your CSV column name

        for attempt in range(3):  # Retry mechanism
            try:
                # Fetch the initial page to set cookies
                logging.info(f"Fetching cookies for {report_link}")
                session.get(report_link, headers=headers)

                # Construct the API URL
                api_url = f"https://www.nseindia.com/api/corp-info?symbol={report_link.split('=')[-1]}&corpType=annualreport&market=sme"
                
                # Send GET request to the API
                response = session.get(api_url, headers=headers)

                # Check for successful response
                if response.status_code == 200:
                    data = response.json()  # Parse JSON response
                    # Write the data directly to the CSV file
                    output_file.write(f"{data}\n")  # Adjust the formatting based on the structure of your data
                    logging.info(f"Data fetched and written successfully for {report_link}.")
                    break  # Exit the retry loop on success
                else:
                    logging.warning(f"Failed to fetch data for {report_link}. Status code: {response.status_code}")

            except requests.exceptions.RequestException as e:
                logging.error(f"Error fetching data for {report_link} (attempt {attempt + 1}): {e}")
                time.sleep(5)  # Wait before retrying
            except Exception as e:
                logging.critical(f"An unexpected error occurred for {report_link}: {e}")
                break  # Exit the retry loop on unexpected error

        # Pause between requests to avoid overwhelming the server
        sleep_time = random.uniform(5, 10)  # Random sleep between 5 and 10 seconds
        logging.info(f"Waiting for {sleep_time:.2f} seconds before the next request...")
        time.sleep(sleep_time)

logging.info(f"Data extraction complete. Saved to {output_csv_path}.")
# Out:
# INFO:root:CSV file loaded successfully.
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SHERA
# INFO:root:Data fetched and written successfully for https://www.nseindia.com/get-quotes/equity?symbol=SHERA.
# INFO:root:Waiting for 8.96 seconds before the next request...
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SANGANI
# INFO:root:Data fetched and written successfully for https://www.nseindia.com/get-quotes/equity?symbol=SANGANI.
# INFO:root:Waiting for 7.35 seconds before the next request...
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=DKEGL
# ERROR:root:Error fetching data for https://www.nseindia.com/get-quotes/equity?symbol=DKEGL (attempt 1): Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ...

# %%
import requests
import pandas as pd
import time
import random
import logging
import urllib.parse

# Set up logging
logging.basicConfig(level=logging.INFO)

# Paths for input and output CSV files
input_csv_path = '/home/shubh/project/nse_links.csv'
output_csv_path = '/home/shubh/project/extracted_data.csv'

# Load the CSV file containing the NSE links
df = pd.read_csv(input_csv_path)
logging.info("CSV file loaded successfully.")

# Initialize a session
session = requests.Session()

# User-agent for the requests
user_agent = "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0"

# Open the output CSV file and write headers
with open(output_csv_path, 'w') as output_file:
    output_file.write('symbol,companyName,fromYr,toYr,fileName,anReportCreateDate\n')

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        report_link = row['report_link']
        nse_code = report_link.split('=')[-1]  # Extract NSE code from URL
        encoded_nse_code = urllib.parse.quote(nse_code)  # Encode the NSE code for URL

        for attempt in range(3):  # Retry mechanism
            try:
                # Step 1: Make an initial request to get cookies
                logging.info(f"Fetching cookies for {report_link}")
                session.get(f'https://www.nseindia.com/get-quotes/equity?symbol={nse_code}', headers={
                    'User-Agent': user_agent,
                    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
                })
                
                # Wait briefly to ensure cookies are set
                time.sleep(2)

                # Step 2: Use the session with cookies to fetch the API data
                api_url = f"https://www.nseindia.com/api/annual-reports?index=equities&symbol={encoded_nse_code}&issuer={encoded_nse_code}"
                headers = {
                    'User-Agent': user_agent,
                    'Accept': 'application/json, text/javascript, */*; q=0.01',
                    'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={encoded_nse_code}',
                    'X-Requested-With': 'XMLHttpRequest',
                }
                
                # Send GET request to the API
                response = session.get(api_url, headers=headers)

                # Check if response content is empty
                if not response.content:
                    logging.warning(f"Empty response for {api_url}")
                    continue

                # Check for successful response
                if response.status_code == 200:
                    try:
                        data = response.json()  # Parse JSON response
                        for item in data:
                            # Write each item in the JSON array to the CSV file
                            output_file.write(
                                f"{item['symbol']},{item['companyName']},{item['fromYr']},{item['toYr']},{item['fileName']},{item['anReportCreateDate']}\n"
                            )
                        logging.info(f"Data fetched and written successfully for {report_link}.")
                    except ValueError as e:
                        logging.error(f"JSON decode error for {report_link}: {e}")
                    break  # Exit the retry loop on success
                else:
                    logging.warning(f"Failed to fetch data for {report_link}. Status code: {response.status_code}")

            except requests.exceptions.RequestException as e:
                logging.error(f"Error fetching data for {report_link} (attempt {attempt + 1}): {e}")
                time.sleep(5)  # Wait before retrying
            except Exception as e:
                logging.critical(f"An unexpected error occurred for {report_link}: {e}")
                break  # Exit the retry loop on unexpected error

        # Pause between requests
        sleep_time = random.uniform(5, 10)  # Random sleep between 5 and 10 seconds
        logging.info(f"Waiting for {sleep_time:.2f} seconds before the next request...")
        time.sleep(sleep_time)

logging.info(f"Data extraction complete. Saved to {output_csv_path}.")
# Out:
# INFO:root:CSV file loaded successfully.
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SHERA
# CRITICAL:root:An unexpected error occurred for https://www.nseindia.com/get-quotes/equity?symbol=SHERA: string indices must be integers
# INFO:root:Waiting for 5.37 seconds before the next request...
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SANGANI
# CRITICAL:root:An unexpected error occurred for https://www.nseindia.com/get-quotes/equity?symbol=SANGANI: string indices must be integers
# INFO:root:Waiting for 9.49 seconds before the next request...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 90
#      88         sleep_time = random.uniform(5, 10)  # Random sleep between 5 and 10 seconds
#      89         logging.info(f"Waiting for {sleep_time:.2f} seconds before the next request...")
# ...

# %%
import requests
import pandas as pd
import time
import random
import logging
import urllib.parse

# Set up logging
logging.basicConfig(level=logging.INFO)

# Paths for input and output CSV files
input_csv_path = '/home/shubh/project/nse_links.csv'
output_csv_path = '/home/shubh/project/extracted_data.csv'

# Load the CSV file containing the NSE links
df = pd.read_csv(input_csv_path)
logging.info("CSV file loaded successfully.")

# Initialize a session
session = requests.Session()

# Define headers for requests
common_headers = {
    'User-Agent': "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0",
    'Accept': 'application/json, text/javascript, */*; q=0.01',
}

# DataFrame to collect extracted data
extracted_data = pd.DataFrame(columns=['symbol', 'companyName', 'fromYr', 'toYr', 'fileName', 'anReportCreateDate'])

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    report_link = row['report_link']
    nse_code = report_link.split('=')[-1]  # Extract NSE code from URL
    encoded_nse_code = urllib.parse.quote(nse_code)  # Encode the NSE code for URL

    for attempt in range(3):  # Retry mechanism
        try:
            # Step 1: Make an initial request to get cookies
            logging.info(f"Fetching cookies for {report_link}")
            response = session.get(f'https://www.nseindia.com/get-quotes/equity?symbol={nse_code}', headers={
                **common_headers,
                'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            })

            # Check for successful response
            if response.status_code != 200:
                logging.warning(f"Initial cookie fetch failed with status {response.status_code}")
                time.sleep(3)  # Short delay before retry
                continue  # Retry if not successful

            # Wait briefly to ensure cookies are set
            time.sleep(2)

            # Step 2: Use the session with cookies to fetch the API data
            api_url = f"https://www.nseindia.com/api/annual-reports?index=equities&symbol={encoded_nse_code}&issuer={encoded_nse_code}"
            headers = {
                **common_headers,
                'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={encoded_nse_code}',
                'X-Requested-With': 'XMLHttpRequest',
            }

            # Send GET request to the API
            response = session.get(api_url, headers=headers)
            print(response)
            # Check for successful response
            if response.status_code != 200:
                logging.warning(f"Failed to fetch data for {report_link}. Status code: {response.status_code}")
                time.sleep(5)  # Extended delay before retry
                continue

            # Check for empty or malformed data in response
            data = response.json()
            print(data)
            if not isinstance(data.get('data'), list):
                logging.error(f"Unexpected data format or empty data: {data}")
                time.sleep(3)  # Delay before retrying
                continue  # Retry if empty data is received

            # Process and collect the response data
            for item in data['data']:
                extracted_data = extracted_data.append({
                    'symbol': item.get('symbol'),
                    'companyName': item.get('companyName'),
                    'fromYr': item.get('fromYr'),
                    'toYr': item.get('toYr'),
                    'fileName': item.get('fileName'),
                    'anReportCreateDate': item.get('anReportCreateDate')
                }, ignore_index=True)

            logging.info(f"Data fetched and appended successfully for {report_link}.")
            break  # Exit the retry loop on success

        except requests.exceptions.RequestException as e:
            logging.error(f"Error fetching data for {report_link} (attempt {attempt + 1}): {e}")
            time.sleep(10)  # Wait longer before retrying to avoid rate limits
        except ValueError as e:
            logging.error(f"JSON decode error for {report_link}: {e}")
            logging.error(f"Response content: {response.content[:500]}")  # Log first 500 chars of response
        except Exception as e:
            logging.critical(f"An unexpected error occurred for {report_link}: {e}")
            break  # Exit the retry loop on unexpected error

    # Pause between requests to avoid rate limiting
    sleep_time = random.uniform(5, 10)  # Random sleep between 5 and 10 seconds
    logging.info(f"Waiting for {sleep_time:.2f} seconds before the next request...")
    time.sleep(sleep_time)

# Save extracted data to CSV once all data is processed
extracted_data.to_csv(output_csv_path, index=False)
logging.info(f"Data extraction complete. Saved to {output_csv_path}.")
# Out:
# INFO:root:CSV file loaded successfully.
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SHERA
# INFO:root:Data fetched and appended successfully for https://www.nseindia.com/get-quotes/equity?symbol=SHERA.
# INFO:root:Waiting for 6.22 seconds before the next request...
# <Response [200]>
# {'data': []}
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SANGANI
# INFO:root:Data fetched and appended successfully for https://www.nseindia.com/get-quotes/equity?symbol=SANGANI.
# INFO:root:Waiting for 6.11 seconds before the next request...
# <Response [200]>
# {'data': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 107
#     105     sleep_time = random.uniform(5, 10)  # Random sleep between 5 and 10 seconds
# ...

# %%
import requests
import pandas as pd
import time
import random
import logging
import urllib.parse

# Set up logging
logging.basicConfig(level=logging.INFO)

# Paths for input and output CSV files
input_csv_path = '/home/shubh/project/nse_links.csv'
output_csv_path = '/home/shubh/project/extracted_data.csv'

# Load the CSV file containing the NSE links
df = pd.read_csv(input_csv_path)
logging.info("CSV file loaded successfully.")

# Initialize a session
session = requests.Session()

# Define headers for requests
common_headers = {
    'User-Agent': "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:131.0) Gecko/20100101 Firefox/131.0",
    'Accept': 'application/json, text/javascript, */*; q=0.01',
}

# Initialize a list to collect data
extracted_data_list = []

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    report_link = row['report_link']
    nse_code = report_link.split('=')[-1]  # Extract NSE code from URL
    encoded_nse_code = urllib.parse.quote(nse_code)  # Encode the NSE code for URL

    for attempt in range(3):  # Retry mechanism
        try:
            # Step 1: Make an initial request to get cookies
            logging.info(f"Fetching cookies for {report_link}")
            response = session.get(f'https://www.nseindia.com/get-quotes/equity?symbol={nse_code}', headers={
                **common_headers,
                'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            })

            # Check for successful response
            if response.status_code != 200:
                logging.warning(f"Initial cookie fetch failed with status {response.status_code}")
                time.sleep(3)  # Short delay before retry
                continue  # Retry if not successful

            # Wait briefly to ensure cookies are set
            time.sleep(2)

            # Step 2: Use the session with cookies to fetch the API data
            api_url = f"https://www.nseindia.com/api/annual-reports?index=equities&symbol={encoded_nse_code}&issuer={encoded_nse_code}"
            headers = {
                **common_headers,
                'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={encoded_nse_code}',
                'X-Requested-With': 'XMLHttpRequest',
            }

            # Send GET request to the API
            response = session.get(api_url, headers=headers)

            # Check for successful response
            if response.status_code != 200:
                logging.warning(f"Failed to fetch data for {report_link}. Status code: {response.status_code}")
                time.sleep(5)  # Extended delay before retry
                continue

            # Check for empty or malformed data in response
            data = response.json()
            if not isinstance(data.get('data'), list) or not data['data']:
                logging.error(f"Unexpected or empty data format: {data}")
                time.sleep(3)  # Delay before retrying
                continue  # Retry if empty data is received

            # Process and collect the response data
            for item in data['data']:
                extracted_data_list.append({
                    'symbol': item.get('symbol'),
                    'companyName': item.get('companyName'),
                    'fromYr': item.get('fromYr'),
                    'toYr': item.get('toYr'),
                    'fileName': item.get('fileName'),
                    'anReportCreateDate': item.get('anReportCreateDate')
                })

            logging.info(f"Data fetched and appended successfully for {report_link}.")
            break  # Exit the retry loop on success

        except requests.exceptions.RequestException as e:
            logging.error(f"Error fetching data for {report_link} (attempt {attempt + 1}): {e}")
            time.sleep(10)  # Wait longer before retrying to avoid rate limits
        except ValueError as e:
            logging.error(f"JSON decode error for {report_link}: {e}")
            logging.error(f"Response content: {response.content[:500]}")  # Log first 500 chars of response
        except Exception as e:
            logging.critical(f"An unexpected error occurred for {report_link}: {e}")
            break  # Exit the retry loop on unexpected error

    # Pause between requests to avoid rate limiting
    sleep_time = random.uniform(5, 10)  # Random sleep between 5 and 10 seconds
    logging.info(f"Waiting for {sleep_time:.2f} seconds before the next request...")
    time.sleep(sleep_time)

# Save collected data to a DataFrame and export to CSV
if extracted_data_list:
    extracted_data_df = pd.DataFrame(extracted_data_list)
    extracted_data_df.to_csv(output_csv_path, index=False)
    logging.info(f"Data extraction complete. Saved to {output_csv_path}.")
else:
    logging.warning("No data extracted. CSV file was not created.")
# Out:
# INFO:root:CSV file loaded successfully.
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SHERA
# ERROR:root:Unexpected or empty data format: {'data': []}
# INFO:root:Fetching cookies for https://www.nseindia.com/get-quotes/equity?symbol=SHERA
# ERROR:root:Unexpected or empty data format: {'data': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 76
#      74 if not isinstance(data.get('data'), list) or not data['data']:
#      75     logging.error(f"Unexpected or empty data format: {data}")
# ---> 76     time.sleep(3)  # Delay before retrying
#      77     continue  # Retry if empty data is received
#      79 # Process and collect the response data
#
# KeyboardInterrupt:

# %%
import requests
import pandas as pd
import time
import random
from tqdm import tqdm  # Progress bar
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from urllib.parse import quote
import os


# Load NSE codes from a CSV file
nse_codes_file = '/home/shubh/project/equity_nse.csv'  # Path to your input CSV file
output_file = '/home/shubh/project/extracted_data.csv'  # Path for the final output CSV file
temp_output_file = '/home/shubh/project/temporary.csv'  # Temporary file to save progress

# Load NSE codes into a list
nse_codes_df = pd.read_csv(nse_codes_file)
nse_codes = nse_codes_df['NSE Code'].tolist()

# %%
# Load NSE codes from a CSV file
nse_codes_file = '/home/shubh/project/equity_nse.csv'  # Path to your input CSV file
output_file = '/home/shubh/project/extracted_data.csv'  # Path for the final output CSV file
temp_output_file = '/home/shubh/project/temporary.csv'  # Temporary file to save progress

# Load NSE codes into a list
nse_codes_df = pd.read_csv(nse_codes_file)
nse_codes = nse_codes_df['NSE Code'].tolist() 



# Load previous results if temp file exists
if os.path.exists(temp_output_file) and os.path.getsize(temp_output_file) > 0:
    previous_results_df = pd.read_csv(temp_output_file)
    fetched_nse_codes = previous_results_df['nse_code'].unique().tolist()
    print(f"Resuming from checkpoint. {len(fetched_nse_codes)} companies already processed.")
else:
    print("No previous data found or file is empty. Starting fresh.")
    fetched_nse_codes = [] 

# Filter out NSE codes that have already been fetched
nse_codes = [code for code in nse_codes if code not in fetched_nse_codes]

# List of rotating User-Agent headers for each request
USER_AGENTS = [
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
]

def fetch_annual_reports(session, nse_code):
    # Rotate User-Agent for each request
    user_agent = random.choice(USER_AGENTS)

    # URL encode the NSE code to handle special characters like & and spaces
    encoded_nse_code = quote(nse_code)

    # Step 1: Make an initial request to get cookies (no need to encode in this URL)
    session.get(f'https://www.nseindia.com/get-quotes/equity?symbol={nse_code}', headers={
        'User-Agent': user_agent,
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    })

    # Step 2: Use the session with cookies to fetch the API data (use encoded NSE code)
    url = f"https://www.nseindia.com/api/annual-reports?index=equities&symbol={encoded_nse_code}&issuer={encoded_nse_code}"
    headers = {
        'User-Agent': user_agent,
        'Accept': 'application/json, text/javascript, */*; q=0.01',
        'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={encoded_nse_code}',
        'X-Requested-With': 'XMLHttpRequest',
    }

    # Add random delay to slow down requests (longer delay between 5-10 seconds)
    delay = random.uniform(1, 6)
    time.sleep(delay)

    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()  # Raise an error for bad responses
        return response.json().get('data', [])
    except requests.exceptions.HTTPError as err:
        print(f"HTTP error occurred for {nse_code}: {err}")
        return []
    except Exception as err:
        print(f"An error occurred for {nse_code}: {err}")
        return []
    
# Initialize a requests session with retry and SSL handling
session = requests.Session()
retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[429, 500, 502, 503, 504])
adapter = HTTPAdapter(max_retries=retries)
session.mount('https://', adapter)

# Initialize results with previously fetched data if any
results = previous_results_df.to_dict('records')    


# Function to save data incrementally
def save_results():
    results_df = pd.DataFrame(results)
    results_df.to_csv(temp_output_file, index=False)
    print(f"Data saved to {temp_output_file}.")


for nse_code in tqdm(nse_codes, desc="Fetching Annual Reports"):
    attempts = 0
    max_attempts = 0  # Set a maximum number of attempts

    while attempts < max_attempts:
        annual_reports = fetch_annual_reports(session, nse_code)
        if annual_reports:
            for report in annual_reports:
                results.append({
                    'nse_code': nse_code,
                    'company_name': report['companyName'],  # Add company name
                    'year': f"{report['fromYr']} - {report['toYr']}",
                    'link': report['fileName']
                })
            # Save progress periodically
            if len(results) % 50 == 0:
                save_results()
            break  # Break if successful
        else:
            attempts += 1
            print(f"Retrying... Attempt {attempts} for {nse_code}")
            time.sleep(1)  # Delay before retrying
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[37], line 14
#      12 # Load previous results if temp file exists
#      13 if os.path.exists(temp_output_file):
# ---> 14     previous_results_df = pd.read_csv(temp_output_file)
#      15     fetched_nse_codes = previous_results_df['nse_code'].unique().tolist()
#      16     print(f"Resuming from checkpoint. {len(fetched_nse_codes)} companies already processed.")
#
# ...
